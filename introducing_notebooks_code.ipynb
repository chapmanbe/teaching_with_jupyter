# %% [markdown]
# # Teaching with Jupyter Notebooks: Code and Output Cells

# %% [markdown]
# ### The Notebooks Consists of Three  Cells
#
# 1. Markdown cells
# 1. **Code cells**
# 1. **Output cells**
#
# In this notebook we will focus on code cells and output cells.
#
# While these three cells are common to all Jupyter kernels, we will be using some IPython [magics](http://ipython.readthedocs.io/en/5.x/interactive/magics.html) that are specfic to the IPython kernel.

# %%
# %%bash
# cat introducing_notebooks.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Teaching with Jupyter Notebooks"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## What is Jupyter?\n",
#     "![Schematic of Jupyter](https://jupyter.readthedocs.io/en/latest/_images/notebook_components.png)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## What Kernels are Available?\n",
#     "### Three Kernels Created by Jupyter Developers\n",
#     "\n",
#     "* IPython\n",
#     "* IRkernel\n",
#     "* IJulia\n",
#     "\n",
#     "### [Community Maintained Kernels](https://github.com/jupyter/jupyter/wiki/Jupyter-kernels)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## What is in a Notebook?\n",
#     "\n",
#     "On the file system, a notebook is a JSON file with a `.ipynb` suffix."
#    ]
#   },
#   {
#    "cell_type": "code",
# ...

# %%
# %%bash
# pwd
# Out:
# /home/jovyan/work/teaching_with_jupyter
